# %%
from IPython.display import display, HTML

display(
    HTML("""
<style>
div.container{width:80% !important;}
div.prompt {min-width:70px;}
div#toc-header{margin-top:150px;}
span.toc-item-num{display:none;}
div.CodeMirror {font-family:Consolas}
div.input {font-family:Consolas}
</style>
"""))
# Out:
# <style>
# div.container{width:80% !important;}
# div.prompt {min-width:70px;}
# div#toc-header{margin-top:150px;}
# span.toc-item-num{display:none;}
# div.CodeMirror {font-family:Consolas}
# div.input {font-family:Consolas}
# </style>

# %% [markdown]
# <b><font color="red" size="6">ch13. 데이터 시각화</font></b>
# # 1절. 시각화 개요
#  - 시각화 라이브러리 : matplotlib, seaborn, folium(지도시각화)
#  - matplotlib : 파이썬에서 가장 많이 사용하는 시각화 라이브러리. 판다스 내부에 포함
#  - seaborn : matplotlib 기반으로 다양한 색, 테마, 차트 기능과 groupby 기능을 추가한 라이브러리.

# %% [markdown]
# # 2절. matplotlib
#  - https://pypi.org/project/matplotlib/
#  - https://matplotlib.org/stable/api/index.html : api reference
#
# ## 2.1 패키지 import 및 기본 설정

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.7.0'

# %%
import matplotlib.pyplot as plt
# from matplotlib import pyplot as plt

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# 한글설정
# warning(경고메세지) 안 보이게 설정
import warnings
# warnings.filterwarnings(action='ignore')
# warning(경고메세지) 보이게 설정
warnings.filterwarnings(action='default')

# %% [markdown]
# ## 2.2 그래프 그리기
#  - matplotlib으로 그래프를 그리기 위한 단계
#      1) 데이터 준비 <br>
#      2) 그래프 생성 <br>
#      3) 그래프 함수로 그래프 그리기 <br>
#      4) 그래프 커스터마이징 <br>
#      5) 그래프 출력 및 저장 <br>

# %%
plt.figure(figsize=(7, 2))  # 2) 그래프 객체 생성, 사이즈(inch)
plt.plot([1, 2, 3], [2, 4, 6])  # 3) 그래프 함수 : 선 그래프 / y값이 같으면 y값 생략 가능(x의 갯수와 동일해야 함)
plt.ylabel('some numbers')  # 4) 그래프 커스터마이징
plt.show()  # 5) 그래프 출력  # [<matplotlib.lines.Line2D at 0x28f30bf3a90>] 제거

# %% [markdown]
# ## 2.3 그래프 영역 나누기
# ### 1) subplot()함수로 서브플롯 추가

# %%
import numpy as np
x = np.arange(0, 10, 0.01)  # 0부터 0.01씩 증가하며 10까지 생성
x.shape
# Out:
# (1000,)

# %%
plt.figure(figsize=(5, 5))
plt.subplot(2, 1, 1)  # 2행 1열의 subplot에서 1번째 subplot에 다음과 같이 그래프 그리기
plt.plot(x, np.sin(x))  # 선 그래프
plt.subplot(2, 2, 3)  # 2행 2열의 subplot에서 3번째 subplot에 다음과 같이 그래프 그리기
# plt.subplot(223)  # 위와 같음
plt.plot(x, np.cos(x))
plt.subplot(2, 2, 4)  # 2행 2열의 subplot에서 4번째 subplot에 다음과 같이 그래프 그리기
plt.plot(x, np.sin(x)*np.cos(x))
plt.show()

# %%
plt.subplot(2, 2, 1); plt.plot(x, np.sin(x))
plt.subplot(2, 2, 2); plt.plot(x, np.sin(x))
plt.subplot(2, 2, 3); plt.plot(x, np.sin(x))
plt.subplot(2, 2, 4); plt.plot(x, np.sin(x))
plt.show()

# %% [markdown]
# ### 2) subplots()함수로 서브플롯 추가
# plot함수에서 색상이나 스타일을 조정 : https://wikidocs.net/92085

# %%
# 2행2열 서브플롯
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(7, 4))
axes[0, 0].plot(x, np.sin(x), color='r', linewidth=10)
axes[0, 1].plot(x, np.cos(x), 'c--')  # color='c', linestyle='--'(대시라인) : (점선)
axes[1, 0].plot(x, np.tanh(x), color='#00AA00')
# axes[1, 0].plot([0, 1, 2, 3], [-1, -0.5, 0, 0.5], 'ko:')  # k:black, marker='o':마커, linestyle=':'(점선)
axes[1, 1].plot(x, np.sin(x)*np.cos(x), 'r-.')

# %%
# 2행2열 서브플롯(for문 사용)
func_list = [np.sin, np.cos, np.tanh, lambda x : np.sin(x)*np.cos(x)]
fmt_list = ['r', 'c--', '#00AA00', 'r-.']
fig, axes = plt.subplots(2, 2, figsize=(7, 4))
# list(enumerate(axes.flat))  # 1차원
for idx, ax in enumerate(axes.flat):
    # print(idx, ax)
    ax.plot(x, func_list[idx](x), fmt_list[idx])

# %%
# 1행4열 서브플롯        # nrows=1 생략시 1행 / sharey=True : y축 공유
fig, axes = plt.subplots(nrows=1, ncols=4, sharey=True, figsize=(12, 3))
for i, ax in enumerate(axes):
    ax.plot(x, func_list[i](x), fmt_list[i])

# %% [markdown]
# ## 2.4 다양한 그래프 그리기
# ### 1) pyplot 함수들 : https://matplotlib.org/api/_as_gen/matplotlib.pyplot.html
# ### 2) matplotlib.pyplot.plot() : 선그래프

# %%
fig, axes = plt.subplots(ncols=2, figsize=(7, 3))
axes[0].plot([[1, 2], [3, 4]],
             [[2, 4], [6, 8]], 'cs-')  # color='c':cyan, marker='s':사각마커, linestyle='-':실선
axes[1].plot([3, 6], [3, 5], 'b^:')    # color='b':blue, marker='^':세모마커, linestyle=':':점선
axes[1].plot([4, 5], [5, 4], 'kx--')   # color='k':balck, marker='x':x마커, linestyle='--':대시드점선

# %% [markdown]
# ### 3) pandas.DataFrame.plot()
#  - plt.plot(x, y, format) <br>
#  - df.plot(x=None, y=None, kind='line', figsize=None, title=None, grid=None, xlim, ylim, ...) <br>
#      * kind : line(기본값), scatter(점도표), bar(막대그래프), barh(가로막대그래프), density(밀도그래프), pie... <br>
#      * figsize : tuple(인치단위) <br>
#      * xlim, ylim : list/tuple (눈금지정)

# %%
import seaborn as sns
iris = sns.load_dataset('iris')
iris.sample(1)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 76           6.8          2.8           4.8          1.4  versicolor

# %% [markdown]
# https://stackoverflow.com/questions/30490740/move-legend-outside-figure-in-seaborn-tsplot : 범례사용

# %%
g = iris.plot(figsize=(8, 2))
# plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
g.legend(loc='center left', bbox_to_anchor=(1, 0.5))  # g를 할당하지 않으면 위와 같이 plt.legend()사용
plt.show()

# %% [markdown]
# https://ko.wikipedia.org/wiki/상자_수염_그림
# https://matplotlib.org/stable/tutorials/colors/colormaps.html (colormap)

# %%
iris.plot(kind='box', figsize=(12, 3), title='IRIS BoxPlot', 
          ylabel='y-value', fontsize=15, colormap='winter')
plt.show()

# %%
iris.corr(numeric_only=True)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
iris.plot(kind='scatter', x='petal_length', y='petal_width', figsize=(12, 3))
plt.show()

# %%
iris.plot(kind='scatter', x='petal_length', y='petal_width', figsize=(12, 3),
         s='sepal_length',  # s:점의 크기, 
         c='sepal_length',  # c:점의 색상
         alpha=.5)  # 투명도
plt.show()

# %%
import seaborn as sns
sns.scatterplot(data=iris, x='petal_length', y='petal_width', hue='species')
plt.show()

# %%
# 종별 boxplot 그리기
iris.groupby('species').plot(kind='box', 
                             subplots=True, 
                             layout=(3, 4), 
                             sharey=True)  # y축 공유
plt.show()

# %% [markdown]
# ### 4) plt.scatter() : 산점도

# %%
x = np.random.rand(50)  # random.rand : 균등분포의 1차원 난수 50개 발생(배열) / rand : 최대값 1.0
y = np.random.rand(50)
colors = np.random.rand(50)
area = (np.random.rand(50)*30)**2
plt.scatter(x, y, s=area, # 점의 크기
            c=colors, # 점의 색상
            alpha=.5 # 투명도 (투명0~불투명1)
           )
plt.show()

# %%
plt.scatter(x=iris.petal_length, y=iris.petal_width,
            c=iris.petal_length*20)

# %% [markdown]
# ## 2.5 그 외 그래프 그리기
# ### 1) fill(), fill_between(), scatter()
# ### 2) bar(), barh(), axvline(), axhline()
# ### 3) hist(히스토그램=밀도그래프), boxplot(분포를 알 수 없음), violinplot()

# %%
x = np.linspace(0, 10, 50)  # 0부터 10까지 일정한 간격으로 50(기본값)개 수 추출
y = np.cos(x)
fig, axes = plt.subplots(2, 2, figsize=(12, 4))
axes[0, 0].scatter(x, y, s=5, marker='v')
axes[0, 1].fill(x, y, c='b')
axes[1, 0].fill_between(x, y, color='r')
axes[1, 0].plot([0, 2], [-1, 1], 'k')
axes[1, 1].axvline(0.5)
axes[1, 1].axhline(0.8, c='r')

# %%
# boxplot() vs. violinplot()
fig, axes = plt.subplots(ncols=2)  # 1행2열
axes[0].boxplot(iris.sepal_length)
axes[0].violinplot(iris.sepal_length)
axes[1].violinplot(iris.sepal_length)
plt.show()
